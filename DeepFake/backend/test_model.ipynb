# %%
import tensorflow as tf
import dlib
import cv2
from tensorflow.keras.models import load_model

# %%
model = load_model("models/model_fine_final.h5")
# Out:
# c:\Users\asimsiddiqui\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.

# %%
input_shape = (128, 128, 3)
pr_data = []
detector = dlib.get_frontal_face_detector()
cap = cv2.VideoCapture("dataset/fake/id0_id1_0006.mp4")
frameRate = cap.get(5)
while cap.isOpened():
    frameId = cap.get(1)
    ret, frame = cap.read()
    if ret != True:
        break
    if frameId % ((int(frameRate) + 1) * 1) == 0:
        face_rects, scores, idx = detector.run(frame, 0)
        for i, d in enumerate(face_rects):
            x1 = d.left()
            y1 = d.top()
            x2 = d.right()
            y2 = d.bottom()
            crop_img = frame[y1:y2, x1:x2]
            data = (cv2.resize(crop_img, (128, 128))) / 255.0
            data = data.reshape(-1, 128, 128, 3)
            prediction = model.predict(data)
            prediction_threshold = 0.5
            if prediction >= prediction_threshold:
                predicted_class = 1
            else:
                predicted_class = 0

            print("Predicted class:", predicted_class)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step
# Predicted class: 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Predicted class: 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Predicted class: 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Predicted class: 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Predicted class: 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Predicted class: 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Predicted class: 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Predicted class: 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Predicted class: 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Predicted class: 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Predicted class: 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Predicted class: 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Predicted class: 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted class: 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Predicted class: 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Predicted class: 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Predicted class: 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Predicted class: 0
